# %%
from selenium_pro import webdriver
driver = webdriver.Start()
# to open new tab
#driver.execute_script("window.open();")

# to open the url in browser
driver.get('https://yandex.com/')

# to type content in input field
driver.find_element_by_pro('nrHPCtiqAVjOZHe').type('universities in USA')
t=[]
l=[]
# press Enter key
driver.switch_to.active_element.type('Enter')

# to fetch the text of element
text=driver.find_element_by_pro('o0Lvq1ZlqZp5IQH').text

# to fetch the link of element
link=driver.find_element_by_pro('xNkToFDbk07XdMq').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('RX3FnNRnj3Hfv2u').text

# to fetch the link of element
link=driver.find_element_by_pro('mI5Kj_WZkb_77u6').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('AaEhozXzXIyoUjW').text

# to fetch the link of element
link=driver.find_element_by_pro('uUsqBOjCXoT_APq').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('EJwqEx37CMrPUtT').text

# to fetch the link of element
link=driver.find_element_by_pro('n5wkcCqG7wnZQ40').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('k7ro_fgPpvAt1_p').text

# to fetch the link of element
link=driver.find_element_by_pro('vvYZieSNIxdEkQ6').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('1BmzlNDXAjCHX7v').text

# to fetch the link of element
link=driver.find_element_by_pro('8QnaXxV10PUIRza').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('1C05nS5vOPOesfw').text

# to fetch the link of element
link=driver.find_element_by_pro('jea45NQfKq5DGsQ').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('VHLw4htv1xR9Aco').text

# to fetch the link of element
link=driver.find_element_by_pro('Xxl9rkUBw_2rOMQ').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('FBBToAAnuBMfSfM').text

# to fetch the link of element
link=driver.find_element_by_pro('J1C_YvO5iCwuhpi').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('8pgvPkjazZw9cCJ').text

# to fetch the link of element
link=driver.find_element_by_pro('bOx9Gz0fEIg08vq').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('V1nGOxEyGILU85W').text

# to fetch the link of element
link=driver.find_element_by_pro('ISnmwNTEM_oIsnC').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('6DC4lmedr3nue_d').text

# to fetch the link of element
link=driver.find_element_by_pro('1RcvlbUHNjF9dlB').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('UOlchg6y452Tazd').text

# to fetch the link of element
link=driver.find_element_by_pro('QVZiW2sf7ui2ryu').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('x4iNmLbtl1kqh6R').text

# to fetch the link of element
link=driver.find_element_by_pro('CvTqlHAeFttzOn1').get_attribute('href')
t.append(text)
l.append(link)

# to click on the element(next) found
driver.find_element_by_pro('EpEcMGKPk63PxUO').click_pro()

# to fetch the text of element
text=driver.find_element_by_pro('bhINaevtP0YbPno').text

# to fetch the link of element
link=driver.find_element_by_pro('6BZN249uWbhW0HU').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('48Tlme75AcmIgsZ').text

# to fetch the link of element
link=driver.find_element_by_pro('PmmGyMb_GeSupCX').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('r5RvjURRhNP1IG1').text

# to fetch the link of element
link=driver.find_element_by_pro('900E53d6s38QPnE').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('ruFMGT_Iofl4XQ8').text

# to fetch the link of element
link=driver.find_element_by_pro('LNXgmeDO9Ao6z5t').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('RDPKTBvm6KpBHxj').text

# to fetch the link of element
link=driver.find_element_by_pro('CYP49EcOUsfdVIW').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('m435lJT7s_hIXOc').text

# to fetch the link of element
link=driver.find_element_by_pro('7eZ4SX2RKnqNO4m').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('enSCtt_2Vi5qmRZ').text

# to fetch the link of element
link=driver.find_element_by_pro('puD9SWqYtHDdWs0').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('z4uxorQvrtIYLAX').text

# to fetch the link of element
link=driver.find_element_by_pro('YsOTvZ1rw1qlZha').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('70KbFVoqPNNjtSM').text

# to fetch the link of element
link=driver.find_element_by_pro('KEPwV21bbCaQzbm').get_attribute('href')
t.append(text)
l.append(link)

print(t)
print(l)
# Out:
# Opening Chrome...
# ['in', 'Universities in the USA | List of American colleges and...', '100+ Best Universities in the United States [2022 Rankings]', 'Universities', 'Top Universities in the United States | 2022 US University...', 'Ranked: The top 100 universities in the USA', 'Universities', '265 Top-Ranked Universities in United... - Mastersportal.com', 'Best universities in the United States 2022 - University...', '2023 Top Public Universities in America - Niche', 'Best Universities in the USA in 2021-2022 | CWUR', 'USA', 'ДипМастер. Сервис для студентов и аспирантов', 'Зарубежное обучение в Дубае, ОАЭ. Учись и работай!', 'in', 'Universities in USA | universities in United States of...', 'usa', 'List Of Universities In USA | Postgrad', 'Top 300 Colleges and Universities of USA', '25 Best Universities in USA for International Students', 'Top Universities in USA | Courses, Admission, Ranking...', 'USA', 'USA']
# ...

# %%
t1 = t[:20]
l1 = l[:20]

# %%
t2 = t[:20]
l2 = l[:20]

# %%
data = {"IT_companies_Bangalore_name":t2,"IT_companies_Bangalore_links":l2}
import pandas as pd
data_yandex = pd.DataFrame(data)
data_yandex
# Out:
#                           IT_companies_Bangalore_name  \
# 0                                           Companies
# 1   The Best It Companies in Bangalore And Places ...
# 2     Top 24 IT Companies in Bangalore - InterviewBit
# 3                                           Bangalore
# 4   Top Software Companies in Bangalore - Reviews ...
# 5   Top 50 IT Companies In Bangalore - List Of IT ...
# 6                                                  IT
# 7   Top 10 IT Companies in Bangalore in 2021 - Sta...
# 8              IT Companies in Bangalore - Grotal.com
# 9   List of Top IT Companies in Bangalore - with e...
# 10  List of Software Companies in Bangalore With C...
# 11                                                 in
# 12      Ites companies in Bangalore List 2022 Updated
# 13  Top 10 IT Companies in Bangalore//top companie...
# 14                                          Bangalore
# 15  Top 10 Mobile App Development Companies in Ban...
# ...

# %%
data_yandex['colleges_delhi_name']=t1
data_yandex['colleges_delhi_links']=l1
data_yandex
# Out:
#                           IT_companies_Bangalore_name  \
# 0                                           Companies
# 1   The Best It Companies in Bangalore And Places ...
# 2     Top 24 IT Companies in Bangalore - InterviewBit
# 3                                           Bangalore
# 4   Top Software Companies in Bangalore - Reviews ...
# 5   Top 50 IT Companies In Bangalore - List Of IT ...
# 6                                                  IT
# 7   Top 10 IT Companies in Bangalore in 2021 - Sta...
# 8              IT Companies in Bangalore - Grotal.com
# 9   List of Top IT Companies in Bangalore - with e...
# 10  List of Software Companies in Bangalore With C...
# 11                                                 in
# 12      Ites companies in Bangalore List 2022 Updated
# 13  Top 10 IT Companies in Bangalore//top companie...
# 14                                          Bangalore
# 15  Top 10 Mobile App Development Companies in Ban...
# ...
