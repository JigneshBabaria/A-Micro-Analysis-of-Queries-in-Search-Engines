# %%
from selenium_pro import webdriver
driver = webdriver.Start()
# to open the url in browser
driver.get('https://www.ask.com/')

# to click on input field
driver.find_element_by_pro('R9Mk8uwkPgOjIFI').click_pro()

# to type content in input field
driver.find_element_by_pro('rYmpik3FYDSV4MQ').type('IT companies in banglore')

# press Enter key
driver.switch_to.active_element.type('Enter')
t=[]
l=[]
# to fetch the text of element
text=driver.find_element_by_pro('1ssxzymMANQmFMM').text

# to fetch the link of element
link=driver.find_element_by_pro('nsLktj0IYjNYR6q').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('hbcfAk_InHSSVeo').text

# to fetch the link of element
link=driver.find_element_by_pro('sbQMGY5ayJEvDhn').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('nlo19XLMHTYi9mr').text

# to fetch the link of element
link=driver.find_element_by_pro('7OPL7ymdtMOEEat').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('wQ_fXmJvu_4FaRH').text

# to fetch the link of element
link=driver.find_element_by_pro('PiFEtp_ndWakKaQ').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('EzSnVdFpnRq3ZS8').text

# to fetch the link of element
link=driver.find_element_by_pro('it_stRCZiEnqd_y').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('Gz8p8HBKNxTTQdp').text

# to fetch the link of element
link=driver.find_element_by_pro('3A1gX_4Cs4SV3IJ').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('ywAG61UojrAek1g').text

# to fetch the link of element
link=driver.find_element_by_pro('4hIg5a4DK81oV5z').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('8idvc84Ru5Y94Tc').text

# to fetch the link of element
link=driver.find_element_by_pro('oxIXN0ziGctJIpg').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('u9QAdB5B2CM5Ca4').text

# to fetch the link of element
link=driver.find_element_by_pro('Th2JVfJ8eYx7wSk').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('optEw2TQQCFOlg_').text

# to fetch the link of element
link=driver.find_element_by_pro('PNwgpUSth11H39Q').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('8kngVDpKm5CKf_k').text

# to fetch the link of element
link=driver.find_element_by_pro('_cz2i4SHEu5EpNj').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('d6FB5CmgNsaSkDj').text

# to fetch the link of element
link=driver.find_element_by_pro('X52eB457eyvysX_').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('yP0rb9VLmRmnFme').text

# to fetch the link of element
link=driver.find_element_by_pro('nahcz6HqvJ1k58s').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('59sj7aoGu_cHTNs').text

# to fetch the link of element
link=driver.find_element_by_pro('SyDH6eN4cUmLGNR').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('oPrf92KMoKSoBvr').text

# to fetch the link of element
link=driver.find_element_by_pro('pfdGLDncYzQukcR').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('ieDsUvGtsEYHFBR').text

# to fetch the link of element
link=driver.find_element_by_pro('Ep8nJfyNT9wVsG8').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('XDjPrqJb8eZ_kda').text

# to fetch the link of element
link=driver.find_element_by_pro('bPKL2ACHBWGkD4m').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('7KTgzbectXT0uIP').text

# to fetch the link of element
link=driver.find_element_by_pro('PXI7ELsvd_Z5VXQ').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('2iYRmcDRlwX7BRd').text

# to fetch the link of element
link=driver.find_element_by_pro('tJ0sFLq4XyI4HTJ').get_attribute('href')
t.append(text)
l.append(link)

# to click on the element(2) found
driver.find_element_by_pro('Xxr4gsiRvgHu0bL').click_pro()

# to fetch the text of element
text=driver.find_element_by_pro('fn4QSCBIZfceLDB').text

# to fetch the link of element
link=driver.find_element_by_pro('RN4OMzjmSdkAgzh').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('3xIEQYSur_FbpYq').text

# to fetch the link of element
link=driver.find_element_by_pro('ehv46VYqLC4vJbD').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('Ak_8QfAZfKARnhE').text

# to fetch the link of element
link=driver.find_element_by_pro('Yu2Yu3NARwvCUbA').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('MR1CIg8KNQKHJE4').text

# to fetch the link of element
link=driver.find_element_by_pro('lAAFuj24vo6Pizv').get_attribute('href')
t.append(text)
l.append(link)
# Out:
# Opening Chrome...

# %%
t1 = t[:20]
l1 = l[:20]

# %%
import pandas as pd
data = {'IT_companies_bangalore_name':t1,'IT_companies_bangalore_links':l1}
data_Ask = pd.DataFrame(data)
data_Ask
# Out:
#                           IT_companies_bangalore_name  \
# 0
# 1            Companies That Make Online Shopping Easy
# 2
# 3
# 4   45 Best Software/IT Companies in Bangalore - Zolo
# 5     Top 24 IT Companies in Bangalore - InterviewBit
# 6   IT Companies in Bangalore | Top 15 Software an...
# 7   List of Software Companies in Bangalore - Nauk...
# 8   List of companies in "Information Technology (...
# 9   IT Office in Bangalore: Top 10 IT Companies in...
# 10  List of Information Technology (IT) Companies ...
# 11  List of Top Software Companies in Bangalore - ...
# 12  Top 50 IT Companies In Bangalore - List Of IT ...
# 13  The Best It Companies in Bangalore And Places ...
# 14  What are the Top IT Companies in Bangalore? - ...
# 15           Companies That Make Online Shopping Easy
# 16           Companies That Make Online Shopping Easy
# 17
# 18
# 19  Which areas in Bangalore have most IT companie...
#
#                          IT_companies_bangalore_links
# ...

# %%
from selenium_pro import webdriver
driver = webdriver.Start()
# to open new tab
#driver.execute_script("window.open();")

# to open the url in browser
driver.get('https://www.ask.com/')

# to click on input field
driver.find_element_by_pro('XL6ncUrH5fdhR7v').click_pro()

# to type content in input field
driver.find_element_by_pro('m2sC8y_8GaAmEV8').type('universities in USA')

# press Enter key
driver.switch_to.active_element.type('Enter')
t=[]
l=[]
# to click on the element(2) found
driver.find_element_by_pro('mY4JIioXfGiXHN4').click_pro()

# to fetch the text of element
text=driver.find_element_by_pro('Slyf_hrBnR5Wn2_').text

# to fetch the link of element
link=driver.find_element_by_pro('Ay0v8scnrGwp7iI').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('9oRtgvBPnwjlBOE').text

# to fetch the link of element
link=driver.find_element_by_pro('C5RQxW0cTzuz_xi').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('HIpEo2IZEQnVIvY').text

# to fetch the link of element
link=driver.find_element_by_pro('NY8ytGGWOy2PM5A').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('RUvB8X_hrty1aOE').text

# to fetch the link of element
link=driver.find_element_by_pro('RPrGX2PMpUrFJA5').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('T2A3mx33pc_Tag8').text

# to fetch the link of element
link=driver.find_element_by_pro('F1VNffn12PKG_Rw').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('7Wr49TmxA_Agtkx').text

# to fetch the link of element
link=driver.find_element_by_pro('tXn8TVosj5SyN4L').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('qDibQ2f4xEgAcif').text

# to fetch the link of element
link=driver.find_element_by_pro('KVMFBmU14R5Iv3y').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('NcgCDTyLhaR6EH7').text

# to fetch the link of element
link=driver.find_element_by_pro('vbAQRmcwVUVdw2M').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('zjFGcGnqrDOxGEq').text

# to fetch the link of element
link=driver.find_element_by_pro('wLI6iX90IMGzzTJ').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('8HsG2zoSl_VaKZK').text

# to fetch the link of element
link=driver.find_element_by_pro('07uC6DEatyAVdDg').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('GQJpxGO9BRiTcRc').text

# to fetch the link of element
link=driver.find_element_by_pro('vL6c_WjkNX9iHsV').get_attribute('href')
t.append(text)
l.append(link)
# to click on the element(Next) found
driver.find_element_by_pro('zawL3XtC7th8xh8').click_pro()

# to fetch the text of element
text=driver.find_element_by_pro('6PzDs4ouZlxDqr_').text

# to fetch the link of element
link=driver.find_element_by_pro('yjVRpck0qh2Mdha').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('7FobSFWV8o58uxB').text

# to fetch the link of element
link=driver.find_element_by_pro('Vo5TSqNR3fBY8zs').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('AaYLP801e8jmlM4').text

# to fetch the link of element
link=driver.find_element_by_pro('rf2Mvz7XEgMR8zo').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('CDipMHRCtsOBs7i').text

# to fetch the link of element
link=driver.find_element_by_pro('0eApn9ouIqJarBz').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('sJbqGl4o0txW_oZ').text

# to fetch the link of element
link=driver.find_element_by_pro('4YTApU5TOwkulTL').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('G6UF5Er5enKajiZ').text

# to fetch the link of element
link=driver.find_element_by_pro('EfvJgLlaK3mWh0x').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('EHZrNTvkYn_VI6p').text

# to fetch the link of element
link=driver.find_element_by_pro('IJRaBEzQRxdzq90').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('CSb1X6gnNdR3pRu').text

# to fetch the link of element
link=driver.find_element_by_pro('CqE6uoGZixymemr').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('1n4gyJ_LVUYx5gG').text

# to fetch the link of element
link=driver.find_element_by_pro('dW6rYKwsotqHDDM').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('KA6EGN4XQIY9ar8').text

# to fetch the link of element
link=driver.find_element_by_pro('ljCk_Y6OrVofhnI').get_attribute('href')
t.append(text)
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('t9F8ySZ6aOt_rxw').text

# to fetch the link of element
link=driver.find_element_by_pro('seyfbFsebPxhNG2').get_attribute('href')
t.append(text)
l.append(link)
# to click on the element(Next) found
#driver.find_element_by_pro('ejWtIXvQZtlnoRl').click_pro()

# to fetch the text of element
#text=driver.find_element_by_pro('Xd_wnXUXSpdMFKp').text

# to fetch the link of element
#link=driver.find_element_by_pro('CWqxiwWg51vq0_J').get_attribute('href')
#t.append(text)
#l.append(link)
# to fetch the text of element
#text=driver.find_element_by_pro('TJl5gjwJ_6OuKla').text

# to fetch the link of element
#link=driver.find_element_by_pro('ioqZN87anCNz508').get_attribute('href')
#t.append(text)
#l.append(link)
# to fetch the text of element
#text=driver.find_element_by_pro('QnDWmHJb_Wvl4wS').text

# to fetch the link of element
#link=driver.find_element_by_pro('rSgVq8uVvr6CmJo').get_attribute('href')
#t.append(text)
#l.append(link)
# to fetch the text of element
#text=driver.find_element_by_pro('tpzDpNKankUL5iv').text

# to fetch the link of element
#link=driver.find_element_by_pro('3zbW09sgDQPjHHu').get_attribute('href')
#t.append(text)
#l.append(link)
# to fetch the text of element
#text=driver.find_element_by_pro('5AVJiRs2pOd1QDG').text

# to fetch the link of element
#link=driver.find_element_by_pro('wzD9xt6UoH4DRzs').get_attribute('href')
#t.append(text)
#l.append(link)
# to fetch the text of element
#text=driver.find_element_by_pro('94whkE5CUa0G0Sx').text

# to fetch the link of element
#link=driver.find_element_by_pro('NjqmqctpvjUTAip').get_attribute('href')
#t.append(text)
#l.append(link)
# to fetch the text of element
#text=driver.find_element_by_pro('VjcNDDEeRtN6vyK').text

# to fetch the link of element
#link=driver.find_element_by_pro('WxPZAD1cxuasgRi').get_attribute('href')
#t.append(text)
#l.append(link)
# to fetch the text of element
#text=driver.find_element_by_pro('XyY5Ndh9yteeSd2').text

# to fetch the link of element
#link=driver.find_element_by_pro('xd848l7NR1wYfU2').get_attribute('href')
#t.append(text)
#l.append(link)
# to fetch the text of element
#text=driver.find_element_by_pro('E5Cd6bYgwArdxnD').text

# to fetch the link of element
#link=driver.find_element_by_pro('xkXixKA1JZYTtP5').get_attribute('href')
#t.append(text)
#l.append(link)
# to fetch the text of element
#text=driver.find_element_by_pro('w2usy8tw56KjbCZ').text

# to fetch the link of element
#link=driver.find_element_by_pro('bWy1rvxsWwk_Ci9').get_attribute('href')
#t.append(text)
#l.append(link)
# to fetch the text of element
#text=driver.find_element_by_pro('Ge2_hVEU9Z16IVC').text

# to fetch the link of element
#link=driver.find_element_by_pro('6_MTDkHtIuGXksV').get_attribute('href')
#t.append(text)
#l.append(link)
print(t)
print(l)
# Out:
# Opening Chrome...
# ...

# %%
t1 = t[:20]
l1 = l[:20]

# %%
import pandas as pd
data = {'IT_companies_bangalore_name':t1,'IT_companies_bangalore_links':l1}
data_Ask = pd.DataFrame(data)
data_Ask
# Out:
#                           IT_companies_bangalore_name  \
# 0    50137 It Job Vacancies In Bangalore - Naukri.com
# 1   Top 20 IT Companies in Bangalore for IT Profes...
# 2   Top Software Companies in Bangalore - Reviews ...
# 3   List of Top IT Companies in Bangalore - Worldl...
# 4   Software Product Companies in Bengaluru/Bangal...
# 5   Top 51 IT Companies In Bangalore [Most Updated...
# 6             List of Indian IT companies - Wikipedia
# 7   Top 10 IT Companies in Bangalore to Outsource ...
# 8   Success of the New IT Companies in Bangalore |...
# 9   List of Top 91 Startups in Bangalore - Startup...
# 10   50137 It Job Vacancies In Bangalore - Naukri.com
# 11         Software Companies in Bangalore - Indiacom
# 12             Bangalore IT Companies - Deccan Herald
# 13  IT Companies in Bangalore vs Hyderabad: Now an...
# 14  Top 100 IT Services Companies in Bengaluru - T...
# 15  List of Companies in Bengaluru /Bangalore - Vc...
# ...

# %%
data_Ask['universities_USA_name'] = t1
data_Ask['universities_USA_links'] = l1
data_Ask
# Out:
#                           IT_companies_bangalore_name  \
# 0    50137 It Job Vacancies In Bangalore - Naukri.com
# 1   Top 20 IT Companies in Bangalore for IT Profes...
# 2   Top Software Companies in Bangalore - Reviews ...
# 3   List of Top IT Companies in Bangalore - Worldl...
# 4   Software Product Companies in Bengaluru/Bangal...
# 5   Top 51 IT Companies In Bangalore [Most Updated...
# 6             List of Indian IT companies - Wikipedia
# 7   Top 10 IT Companies in Bangalore to Outsource ...
# 8   Success of the New IT Companies in Bangalore |...
# 9   List of Top 91 Startups in Bangalore - Startup...
# 10   50137 It Job Vacancies In Bangalore - Naukri.com
# 11         Software Companies in Bangalore - Indiacom
# 12             Bangalore IT Companies - Deccan Herald
# 13  IT Companies in Bangalore vs Hyderabad: Now an...
# 14  Top 100 IT Services Companies in Bengaluru - T...
# 15  List of Companies in Bengaluru /Bangalore - Vc...
# ...

# %%
data_Ask.to_csv('Ask links.csv')
