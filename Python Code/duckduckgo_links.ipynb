# %%
from selenium_pro import webdriver
driver = webdriver.Start()
# to open new tab
driver.execute_script("window.open();")

# to open the url in browser
driver.get('https://duckduckgo.com/')

# to click on input field
driver.find_element_by_pro('Q8Wtb_z1Gl6qR7B').click_pro()

# to type content in input field
driver.find_element_by_pro('PTsGshlWX4Lo5ON').type('IT companies in bangalore')

l=[]
t=[]
# press Enter key
driver.switch_to.active_element.type('Enter')

# to fetch the text of element
text=driver.find_element_by_pro('MhCIUjUO0l6Xl_C').text
t.append(text)
# to fetch the link of element
link=driver.find_element_by_pro('UNs3hyCBcKEOcQE').get_attribute('href')
l.append(link)
# to fetch the text of element
text=driver.find_element_by_pro('FHjWcqRpdfQLrZe').text

# to fetch the link of element
link=driver.find_element_by_pro('sxN5AS5cMnJ444G').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('7k6YJQ2bWP95FAA').text

# to fetch the link of element
link=driver.find_element_by_pro('Gkg63h4JPf5BTIb').get_attribute('href')
t.append(text)
l.append(link)


# to fetch the text of element
text=driver.find_element_by_pro('VCaAx5dEtFfwZf8').text

# to fetch the link of element
link=driver.find_element_by_pro('5RhI9NmSDQWJCZj').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('08lriZUEg3bkQUM').text

# to fetch the link of element
link=driver.find_element_by_pro('yLO8w0QPCotubfX').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('vmNz2hTR9qOGFrc').text

# to fetch the link of element
link=driver.find_element_by_pro('7f5wdb5VL1C8XH7').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('cqFPfaVRZ9UQwFm').text

# to fetch the link of element
link=driver.find_element_by_pro('40ZH2hJ_WSb8MRJ').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('uX_1knuSmYFMCDj').text

# to fetch the link of element
link=driver.find_element_by_pro('eXXJ5a5m7AT6k_l').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('Ea0_kJW5uQIWbom').text

# to fetch the link of element
link=driver.find_element_by_pro('3ewYjVbO5I9Kduk').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('TIYnCewsz0f7H4I').text

# to fetch the link of element
link=driver.find_element_by_pro('McbOSYM6lslUJM4').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('aBkjev19lFm0pbL').text

# to fetch the link of element
link=driver.find_element_by_pro('kUiDakdUAdlhCm4').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('I5ilZaABpYNcqNT').text

# to fetch the link of element
link=driver.find_element_by_pro('BYTFoRYe20ncNaG').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('E98fDJt0h2M8H6E').text

# to fetch the link of element
link=driver.find_element_by_pro('6skc8W0bgtL4zfz').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('vWdIy81FN7BDspU').text

# to fetch the link of element
link=driver.find_element_by_pro('wf8bydPGrh82Ryz').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('0djfGLVVSEThhw5').text

# to fetch the link of element
link=driver.find_element_by_pro('PWNqMLE2jmr5JWO').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('fOgvD5wfPKDDrZh').text

# to fetch the link of element
link=driver.find_element_by_pro('csSGH7N64_FOgIe').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('FlcxM5e0AuScsV7').text

# to fetch the link of element
link=driver.find_element_by_pro('ABxmnPq_T9Jsw4i').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('SbE3iC7lYKKdUXf').text

# to fetch the link of element
link=driver.find_element_by_pro('VEMRFGPhHp8hbwj').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('dIaBMUboHYn1eaX').text

# to fetch the link of element
link=driver.find_element_by_pro('yLJSiADlBcYYItf').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('IhCFWYfZ3zydexh').text

# to fetch the link of element
link=driver.find_element_by_pro('D5e87yRs8TRiYir').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('AnGwOx_h6tlHJHs').text

# to fetch the link of element
link=driver.find_element_by_pro('89rint_skGicYRu').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('o2ONjeRuB7fCOvA').text

# to fetch the link of element
link=driver.find_element_by_pro('6njor3yb3Hbdin7').get_attribute('href')
t.append(text)
l.append(link)

# to fetch the text of element
text=driver.find_element_by_pro('ly5Klrpi6C95q9C').text

# to fetch the link of element
link=driver.find_element_by_pro('agj5EMizP3JucOH').get_attribute('href')
t.append(text)
l.append(link)
#print(t,l,sep='\n')
# Out:
# Opening Chrome...

# %%
t1 = t[:20]
l1 = l[:20]

# %%
import pandas as pd
data = {'"IT_companies_bangalore"_name':t1,'"IT_companies_bangalore"_links':l1}
data_DuckDuckGo = pd.DataFrame(data)
data_DuckDuckGo
# Out:
#                         "IT_companies_bangalore"_name  \
# 0   Top 50 IT Companies In Bangalore - List Of IT ...
# 1   Top 50 IT Companies In Bangalore - List Of IT ...
# 2     Top 24 IT Companies in Bangalore - InterviewBit
# 3   45 Best Software/IT Companies in Bangalore | Zolo
# 4   Top 51 IT Companies In Bangalore [Most Updated...
# 5         Top 30 IT Companies in Bangalore - NestAway
# 6   Top 10 IT & Software Companies in Bangalore [U...
# 7   List of Top IT Companies in Bangalore - Home C...
# 8   Best IT Services Companies in Bangalore Review...
# 9   Top IT Consulting Companies in Bangalore 2022 ...
# 10  Top 50 IT Companies In Bangalore - List Of IT ...
# 11  Top 50 IT Companies In Bangalore - List Of IT ...
# 12        Top 30 IT Companies in Bangalore - NestAway
# 13  Top 50 IT Companies In Bangalore - List Of IT ...
# 14  Top 50 IT Companies In Bangalore - List Of IT ...
# 15  Top IT Consulting Companies in Bangalore 2022 ...
# ...

# %%
data_DuckDuckGo['IT_companies_Bangalore_name'] = t1
data_DuckDuckGo['IT_companies_Bangalore_links'] = l1
data_DuckDuckGo
# Out:
#                         "IT_companies_bangalore"_name  \
# 0   Top 50 IT Companies In Bangalore - List Of IT ...
# 1   Top 50 IT Companies In Bangalore - List Of IT ...
# 2     Top 24 IT Companies in Bangalore - InterviewBit
# 3   45 Best Software/IT Companies in Bangalore | Zolo
# 4   Top 51 IT Companies In Bangalore [Most Updated...
# 5         Top 30 IT Companies in Bangalore - NestAway
# 6   Top 10 IT & Software Companies in Bangalore [U...
# 7   List of Top IT Companies in Bangalore - Home C...
# 8   Best IT Services Companies in Bangalore Review...
# 9   Top IT Consulting Companies in Bangalore 2022 ...
# 10  Top 50 IT Companies In Bangalore - List Of IT ...
# 11  Top 50 IT Companies In Bangalore - List Of IT ...
# 12        Top 30 IT Companies in Bangalore - NestAway
# 13  Top 50 IT Companies In Bangalore - List Of IT ...
# 14  Top 50 IT Companies In Bangalore - List Of IT ...
# 15  Top IT Consulting Companies in Bangalore 2022 ...
# ...
